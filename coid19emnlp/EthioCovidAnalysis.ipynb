# %%
import pandas as pd
from datetime import datetime
import glob
import matplotlib.pyplot as plt
from wordcloud import WordCloud
% matplotlib inline
# Out:
# UsageError: Line magic function `%` not found.

# %%
df = pd.read_csv("covid19.csv", index_col=0)

# %%
korona = df[df['tweet'].str.contains("ኮቪድ")]
print("Covid", len(korona))

korona = df[df['tweet'].str.contains("ኮሮና")]
print("Corona", len(korona))

korona = df[df['tweet'].str.contains("ማስክ")]
print("Mask", len(korona))

korona = df[df['tweet'].str.contains("sanitizer")]
print("Sanitizer", len(korona))

korona = df[df['tweet'].str.contains("COVID")]
print("COVID", len(korona))

korona = df[df['tweet'].str.contains("Corona")]
print("Corona", len(korona))
# Out:
# Covid 2176
# Corona 17632
# Mask 643
# Sanitizer 27
# COVID 3926
# Corona 799

# %%
df2 = df[~df['tweet'].str.startswith('RT')]

# %%
len(df), len(df2)
# Out:
# (268960, 176633)

# %%
text2 = " ".join(tweet for tweet in df2[df2['tweet'].str.contains("ኳራንቲ")].tweet)

# %%
wordcloud = WordCloud(background_color="white",font_path="Tera-Regular.ttf").generate(text2)

# Display the generated image:
# the matplotlib way:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
keyword = ["ኮቪድ", "ኮሮና", "ቫይረስ", "ወረርሽኝ", "ኳራንቲን", "ማስክ", "ሳኒታይዘር", "ሴኒታይዘር", "ውሽባ", "ወሸባ", "ውሸባ", "ማህበራዊ ርቀት", "በሽታ","ማገገም","ተጋላጭ","ሳሙና"]
